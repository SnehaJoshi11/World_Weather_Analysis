# %%
#import dependancies
import pandas as pd

import numpy as np
from citipy import citipy
import requests
#from config import weather_api_key

# %%
#import keys by other way
import sys 

sys.path.append("C:/Users/Ameysne/api")

from api_key import weather_api_key
api_key = weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats=np.random.uniform(low=-90.000,high=90.000,size=2000)

lngs=np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %% [markdown]
#     Retrieve the following information from the API call:
#     - Latitude and longitude
#     - Maximum temperature
#     - Percent humidity
#     - Percent cloudiness
#     - Wind speed
#     - Weather description (for example, clouds, fog, light rain, clear sky)

# %%
#Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.    
for i, city  in enumerate (cities):
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count +=1
        record_count +=1
        time.sleep(60) 
        # Create endpoint URL with each city.
    city_url = url + "&q=" +city.replace(" ", " +")
        # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        # Add 1 to the record count.
    record_count += 1
        # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
       
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          #"Visibility":visibiity,
                          "Current Description": weather_description,
                          #"Rain inches (last 3 hours)": rain_inches,
                          #"Snow inches (last 3 hours)": snow_inches,
                          "Country": city_country})
                          #"Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zhigansk
# Processing Record 2 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 3 of Set 1 | sucua
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | east london
# City not found. Skipping...
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | shache
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | richards bay
# City not found. Skipping...
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | pacocha
# Processing Record 17 of Set 1 | pemba
# Processing Record 18 of Set 1 | beringovskiy
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 1 | yeppoon
# Processing Record 23 of Set 1 | guerrero negro
# City not found. Skipping...
# Processing Record 24 of Set 1 | severo-kurilsk
# Processing Record 25 of Set 1 | puerto del rosario
# City not found. Skipping...
# Processing Record 26 of Set 1 | baruun-urt
# Processing Record 27 of Set 1 | arraial do cabo
# City not found. Skipping...
# Processing Record 28 of Set 1 | faanui
# Processing Record 29 of Set 1 | saint anthony
# City not found. Skipping...
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | norman wells
# City not found. Skipping...
# Processing Record 32 of Set 1 | torbay
# Processing Record 33 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 1 | bobo dioulasso
# City not found. Skipping...
# Processing Record 35 of Set 1 | jimeta
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | port blair
# City not found. Skipping...
# Processing Record 40 of Set 1 | encheng
# Processing Record 41 of Set 1 | klaksvik
# Processing Record 42 of Set 1 | yulara
# Processing Record 43 of Set 1 | linxia
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | kulhudhuffushi
# Processing Record 46 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 47 of Set 1 | moranbah
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | ambon
# Processing Record 52 of Set 2 | takestan
# Processing Record 53 of Set 2 | hithadhoo
# Processing Record 54 of Set 2 | nikolskoye
# Processing Record 55 of Set 2 | avarua
# Processing Record 56 of Set 2 | harper
# Processing Record 57 of Set 2 | jamestown
# Processing Record 58 of Set 2 | muyezerskiy
# Processing Record 59 of Set 2 | mar del plata
# City not found. Skipping...
# Processing Record 60 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 61 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 62 of Set 2 | tuktoyaktuk
# Processing Record 63 of Set 2 | port alfred
# City not found. Skipping...
# Processing Record 64 of Set 2 | busselton
# Processing Record 65 of Set 2 | paytug
# City not found. Skipping...
# Processing Record 66 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 67 of Set 2 | sioux lookout
# City not found. Skipping...
# Processing Record 68 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 69 of Set 2 | eyl
# Processing Record 70 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 71 of Set 2 | san andres
# City not found. Skipping...
# Processing Record 72 of Set 2 | kavieng
# Processing Record 73 of Set 2 | winneba
# Processing Record 74 of Set 2 | tabou
# Processing Record 75 of Set 2 | xuddur
# Processing Record 76 of Set 2 | mabaruma
# Processing Record 77 of Set 2 | spearfish
# Processing Record 78 of Set 2 | spornoye
# Processing Record 79 of Set 2 | hilo
# Processing Record 80 of Set 2 | bengkulu
# Processing Record 81 of Set 2 | bredasdorp
# Processing Record 82 of Set 2 | ambalavao
# Processing Record 83 of Set 2 | talnakh
# Processing Record 84 of Set 2 | lata
# Processing Record 85 of Set 2 | saint-pierre
# Processing Record 86 of Set 2 | sao filipe
# City not found. Skipping...
# Processing Record 87 of Set 2 | flin flon
# City not found. Skipping...
# Processing Record 88 of Set 2 | gejiu
# Processing Record 89 of Set 2 | makakilo city
# City not found. Skipping...
# Processing Record 90 of Set 2 | shahumyan
# Processing Record 91 of Set 2 | airai
# Processing Record 92 of Set 2 | tautira
# Processing Record 93 of Set 2 | coahuayana
# Processing Record 94 of Set 2 | fereydun kenar
# City not found. Skipping...
# Processing Record 95 of Set 2 | upernavik
# Processing Record 96 of Set 2 | malakal
# Processing Record 97 of Set 2 | butaritari
# Processing Record 98 of Set 2 | cayenne
# Processing Record 99 of Set 2 | lamar
# Processing Record 100 of Set 2 | cabo san lucas
# City not found. Skipping...
# Processing Record 101 of Set 2 | chimbarongo
# Processing Record 103 of Set 3 | new norfolk
# City not found. Skipping...
# Processing Record 104 of Set 3 | turayf
# Processing Record 105 of Set 3 | marsh harbour
# City not found. Skipping...
# Processing Record 106 of Set 3 | kedainiai
# Processing Record 107 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 108 of Set 3 | sunland park
# City not found. Skipping...
# Processing Record 109 of Set 3 | sistranda
# Processing Record 110 of Set 3 | garden city
# City not found. Skipping...
# Processing Record 111 of Set 3 | labrea
# Processing Record 112 of Set 3 | victoria
# Processing Record 113 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 114 of Set 3 | douentza
# Processing Record 115 of Set 3 | georgetown
# Processing Record 116 of Set 3 | tambovka
# Processing Record 117 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 118 of Set 3 | general roca
# City not found. Skipping...
# Processing Record 119 of Set 3 | sesheke
# Processing Record 120 of Set 3 | vangaindrano
# Processing Record 121 of Set 3 | thompson
# Processing Record 122 of Set 3 | teya
# Processing Record 123 of Set 3 | katsuura
# Processing Record 124 of Set 3 | puerto ayora
# City not found. Skipping...
# Processing Record 125 of Set 3 | huarmey
# Processing Record 126 of Set 3 | chuy
# Processing Record 127 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 128 of Set 3 | mayo
# Processing Record 129 of Set 3 | tiksi
# Processing Record 130 of Set 3 | pevek
# Processing Record 131 of Set 3 | mitu
# Processing Record 132 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 133 of Set 3 | bayburt
# Processing Record 134 of Set 3 | mzimba
# Processing Record 135 of Set 3 | hay river
# City not found. Skipping...
# Processing Record 136 of Set 3 | sarkand
# Processing Record 137 of Set 3 | iqaluit
# Processing Record 138 of Set 3 | kruisfontein
# Processing Record 139 of Set 3 | ribeira grande
# City not found. Skipping...
# Processing Record 140 of Set 3 | itarema
# Processing Record 141 of Set 3 | hobart
# Processing Record 142 of Set 3 | kati
# Processing Record 143 of Set 3 | ichinoseki
# Processing Record 144 of Set 3 | inirida
# Processing Record 145 of Set 3 | santa barbara
# City not found. Skipping...
# Processing Record 146 of Set 3 | omsukchan
# Processing Record 147 of Set 3 | dejen
# Processing Record 148 of Set 3 | kaputa
# Processing Record 149 of Set 3 | mubi
# Processing Record 150 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 151 of Set 3 | sola
# Processing Record 152 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 154 of Set 4 | coquimbo
# Processing Record 155 of Set 4 | chokurdakh
# Processing Record 156 of Set 4 | phan thiet
# City not found. Skipping...
# Processing Record 157 of Set 4 | rabo de peixe
# City not found. Skipping...
# Processing Record 158 of Set 4 | vaitape
# Processing Record 159 of Set 4 | cotonou
# Processing Record 160 of Set 4 | bambous virieux
# City not found. Skipping...
# Processing Record 161 of Set 4 | bertoua
# Processing Record 162 of Set 4 | helong
# Processing Record 163 of Set 4 | togur
# Processing Record 164 of Set 4 | marsa matruh
# City not found. Skipping...
# Processing Record 165 of Set 4 | palembang
# Processing Record 166 of Set 4 | dalaba
# Processing Record 167 of Set 4 | jiuquan
# Processing Record 168 of Set 4 | los llanos de aridane
# City not found. Skipping...
# Processing Record 169 of Set 4 | mahebourg
# Processing Record 170 of Set 4 | chardara
# Processing Record 171 of Set 4 | aklavik
# Processing Record 172 of Set 4 | kavaratti
# Processing Record 173 of Set 4 | sulangan
# Processing Record 174 of Set 4 | kuala terengganu
# City not found. Skipping...
# Processing Record 175 of Set 4 | gamba
# Processing Record 176 of Set 4 | alegrete
# Processing Record 177 of Set 4 | bowen
# Processing Record 178 of Set 4 | biak
# Processing Record 179 of Set 4 | hamilton
# Processing Record 180 of Set 4 | isangel
# Processing Record 181 of Set 4 | atar
# Processing Record 182 of Set 4 | njeru
# Processing Record 183 of Set 4 | neuquen
# Processing Record 184 of Set 4 | cabedelo
# Processing Record 185 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 186 of Set 4 | kismayo
# Processing Record 187 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 188 of Set 4 | luderitz
# Processing Record 189 of Set 4 | pisco
# Processing Record 190 of Set 4 | lavrentiya
# Processing Record 191 of Set 4 | carlisle
# Processing Record 192 of Set 4 | cidreira
# Processing Record 193 of Set 4 | pacific grove
# City not found. Skipping...
# Processing Record 194 of Set 4 | tieli
# Processing Record 195 of Set 4 | mujiayingzi
# Processing Record 196 of Set 4 | hornepayne
# Processing Record 197 of Set 4 | mount gambier
# City not found. Skipping...
# Processing Record 198 of Set 4 | sitka
# Processing Record 199 of Set 4 | lorengau
# Processing Record 200 of Set 4 | brae
# Processing Record 201 of Set 4 | port lincoln
# City not found. Skipping...
# Processing Record 202 of Set 4 | itacarambi
# Processing Record 203 of Set 4 | narsaq
# Processing Record 205 of Set 5 | dikson
# Processing Record 206 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 207 of Set 5 | ixtapa
# Processing Record 208 of Set 5 | lebu
# Processing Record 209 of Set 5 | hualmay
# Processing Record 210 of Set 5 | souillac
# Processing Record 211 of Set 5 | sarankhola
# Processing Record 212 of Set 5 | port hardy
# City not found. Skipping...
# Processing Record 213 of Set 5 | pokhara
# Processing Record 214 of Set 5 | vila velha
# City not found. Skipping...
# Processing Record 215 of Set 5 | siva
# Processing Record 216 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 217 of Set 5 | rocha
# Processing Record 218 of Set 5 | salalah
# Processing Record 219 of Set 5 | adrar
# Processing Record 220 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 221 of Set 5 | santiago del estero
# City not found. Skipping...
# Processing Record 222 of Set 5 | portland
# Processing Record 223 of Set 5 | sao joao da barra
# City not found. Skipping...
# Processing Record 224 of Set 5 | maxixe
# Processing Record 225 of Set 5 | kahului
# Processing Record 226 of Set 5 | brive-la-gaillarde
# Processing Record 227 of Set 5 | bethel
# Processing Record 228 of Set 5 | oussouye
# Processing Record 229 of Set 5 | bangassou
# Processing Record 230 of Set 5 | havre-saint-pierre
# Processing Record 231 of Set 5 | longyearbyen
# Processing Record 232 of Set 5 | sigli
# Processing Record 233 of Set 5 | wismar
# Processing Record 234 of Set 5 | puerto escondido
# City not found. Skipping...
# Processing Record 235 of Set 5 | payakumbuh
# Processing Record 236 of Set 5 | birao
# Processing Record 237 of Set 5 | shenjiamen
# Processing Record 238 of Set 5 | fortuna
# Processing Record 239 of Set 5 | abu dhabi
# City not found. Skipping...
# Processing Record 240 of Set 5 | loviisa
# Processing Record 241 of Set 5 | pokrovka
# Processing Record 242 of Set 5 | khani
# Processing Record 243 of Set 5 | salamiyah
# Processing Record 244 of Set 5 | robertsport
# Processing Record 245 of Set 5 | bacolod
# Processing Record 246 of Set 5 | yellowknife
# Processing Record 247 of Set 5 | teguldet
# Processing Record 248 of Set 5 | sabha
# Processing Record 249 of Set 5 | dwarka
# Processing Record 250 of Set 5 | praia da vitoria
# City not found. Skipping...
# Processing Record 251 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 252 of Set 5 | hofn
# Processing Record 253 of Set 5 | dingle
# Processing Record 254 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 256 of Set 6 | batagay-alyta
# Processing Record 257 of Set 6 | san cristobal
# City not found. Skipping...
# Processing Record 258 of Set 6 | vanavara
# Processing Record 259 of Set 6 | nuuk
# Processing Record 260 of Set 6 | bahir dar
# City not found. Skipping...
# Processing Record 261 of Set 6 | buraydah
# Processing Record 262 of Set 6 | port elizabeth
# City not found. Skipping...
# Processing Record 263 of Set 6 | lagoa
# Processing Record 264 of Set 6 | ilulissat
# Processing Record 265 of Set 6 | palmas
# Processing Record 266 of Set 6 | vila franca do campo
# City not found. Skipping...
# Processing Record 267 of Set 6 | tambura
# Processing Record 268 of Set 6 | northam
# Processing Record 269 of Set 6 | mbini
# Processing Record 270 of Set 6 | banyo
# Processing Record 271 of Set 6 | vawkavysk
# Processing Record 272 of Set 6 | gobabis
# Processing Record 273 of Set 6 | panalingaan
# Processing Record 274 of Set 6 | asau
# Processing Record 275 of Set 6 | port-cartier
# Processing Record 276 of Set 6 | poum
# Processing Record 277 of Set 6 | la ronge
# City not found. Skipping...
# Processing Record 278 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 279 of Set 6 | berlevag
# Processing Record 280 of Set 6 | hobyo
# Processing Record 281 of Set 6 | maldonado
# Processing Record 282 of Set 6 | raudeberg
# Processing Record 283 of Set 6 | do gonbadan
# City not found. Skipping...
# Processing Record 284 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 285 of Set 6 | xining
# Processing Record 286 of Set 6 | te anau
# City not found. Skipping...
# Processing Record 287 of Set 6 | rock sound
# City not found. Skipping...
# Processing Record 288 of Set 6 | arlit
# Processing Record 289 of Set 6 | belyy yar
# City not found. Skipping...
# Processing Record 290 of Set 6 | geraldton
# Processing Record 291 of Set 6 | leningradskiy
# Processing Record 292 of Set 6 | aljezur
# Processing Record 293 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 294 of Set 6 | mezhdurechensk
# Processing Record 295 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 296 of Set 6 | tlahualilo
# City not found. Skipping...
# Processing Record 297 of Set 6 | manokwari
# Processing Record 298 of Set 6 | lagos
# Processing Record 299 of Set 6 | roebourne
# Processing Record 300 of Set 6 | kailua
# Processing Record 301 of Set 6 | coos bay
# City not found. Skipping...
# Processing Record 302 of Set 6 | dutlwe
# Processing Record 303 of Set 6 | mahibadhoo
# Processing Record 304 of Set 6 | zhangjiakou
# Processing Record 305 of Set 6 | sorland
# Processing Record 307 of Set 7 | road town
# City not found. Skipping...
# Processing Record 308 of Set 7 | jacqueville
# Processing Record 309 of Set 7 | usinsk
# Processing Record 310 of Set 7 | shahe
# Processing Record 311 of Set 7 | amazar
# Processing Record 312 of Set 7 | khatanga
# Processing Record 313 of Set 7 | henties bay
# City not found. Skipping...
# Processing Record 314 of Set 7 | kirkel
# Processing Record 315 of Set 7 | magistralnyy
# Processing Record 316 of Set 7 | asfi
# Processing Record 317 of Set 7 | kayes
# Processing Record 318 of Set 7 | villahermosa
# Processing Record 319 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 320 of Set 7 | alta floresta
# City not found. Skipping...
# Processing Record 321 of Set 7 | arman
# Processing Record 322 of Set 7 | jeremie
# Processing Record 323 of Set 7 | satao
# Processing Record 324 of Set 7 | charagua
# Processing Record 325 of Set 7 | ketchikan
# Processing Record 326 of Set 7 | narrabri
# Processing Record 327 of Set 7 | ormara
# Processing Record 328 of Set 7 | ponta do sol
# City not found. Skipping...
# Processing Record 329 of Set 7 | don sak
# City not found. Skipping...
# Processing Record 330 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 331 of Set 7 | krasnoselkup
# Processing Record 332 of Set 7 | burica
# City not found. Skipping...
# Processing Record 333 of Set 7 | port moresby
# City not found. Skipping...
# Processing Record 334 of Set 7 | chatra
# Processing Record 335 of Set 7 | votkinsk
# Processing Record 336 of Set 7 | srednekolymsk
# Processing Record 337 of Set 7 | lambare
# Processing Record 338 of Set 7 | naryan-mar
# Processing Record 339 of Set 7 | iquique
# Processing Record 340 of Set 7 | akyab
# Processing Record 341 of Set 7 | martinsburg
# Processing Record 342 of Set 7 | clyde river
# City not found. Skipping...
# Processing Record 343 of Set 7 | khandyga
# Processing Record 344 of Set 7 | fayaoue
# Processing Record 345 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 346 of Set 7 | venancio aires
# City not found. Skipping...
# Processing Record 347 of Set 7 | cherskiy
# Processing Record 348 of Set 7 | sambava
# Processing Record 349 of Set 7 | alyangula
# Processing Record 350 of Set 7 | eureka
# Processing Record 351 of Set 7 | burnie
# Processing Record 352 of Set 7 | kitoy
# Processing Record 353 of Set 7 | wright
# Processing Record 354 of Set 7 | oranjemund
# Processing Record 355 of Set 7 | inhambane
# Processing Record 356 of Set 7 | antalaha
# Processing Record 358 of Set 8 | kamaishi
# Processing Record 359 of Set 8 | saldanha
# Processing Record 360 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 361 of Set 8 | nalut
# Processing Record 362 of Set 8 | kalmunai
# Processing Record 363 of Set 8 | san carlos de bariloche
# City not found. Skipping...
# Processing Record 364 of Set 8 | vanimo
# Processing Record 365 of Set 8 | naze
# Processing Record 366 of Set 8 | molteno
# Processing Record 367 of Set 8 | lubumbashi
# Processing Record 368 of Set 8 | belle fourche
# City not found. Skipping...
# Processing Record 369 of Set 8 | belmonte
# Processing Record 370 of Set 8 | tomigusuku
# Processing Record 371 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 372 of Set 8 | hearst
# Processing Record 373 of Set 8 | salinopolis
# Processing Record 374 of Set 8 | ancud
# Processing Record 375 of Set 8 | camaqua
# Processing Record 376 of Set 8 | saint-francois
# Processing Record 377 of Set 8 | vao
# Processing Record 378 of Set 8 | dokka
# Processing Record 379 of Set 8 | kachug
# Processing Record 380 of Set 8 | floro
# Processing Record 381 of Set 8 | tecoanapa
# Processing Record 382 of Set 8 | iquitos
# Processing Record 383 of Set 8 | awjilah
# Processing Record 384 of Set 8 | gubkin
# Processing Record 385 of Set 8 | ust-kuyga
# Processing Record 386 of Set 8 | severobaykalsk
# Processing Record 387 of Set 8 | araouane
# Processing Record 388 of Set 8 | ginda
# Processing Record 389 of Set 8 | moa
# Processing Record 390 of Set 8 | kirakira
# Processing Record 391 of Set 8 | tiarei
# Processing Record 392 of Set 8 | lindi
# Processing Record 393 of Set 8 | severnyy-kospashskiy
# Processing Record 394 of Set 8 | anori
# Processing Record 395 of Set 8 | caravelas
# Processing Record 396 of Set 8 | desaguadero
# Processing Record 397 of Set 8 | olinda
# Processing Record 398 of Set 8 | tasiilaq
# Processing Record 399 of Set 8 | mount isa
# City not found. Skipping...
# Processing Record 400 of Set 8 | swan hill
# City not found. Skipping...
# Processing Record 401 of Set 8 | ferkessedougou
# Processing Record 402 of Set 8 | grindavik
# Processing Record 403 of Set 8 | esperance
# Processing Record 404 of Set 8 | roald
# Processing Record 405 of Set 8 | hit
# Processing Record 406 of Set 8 | provideniya
# Processing Record 407 of Set 8 | nanortalik
# Processing Record 409 of Set 9 | ayan
# Processing Record 410 of Set 9 | cockburn town
# City not found. Skipping...
# Processing Record 411 of Set 9 | sinnamary
# Processing Record 412 of Set 9 | lisakovsk
# Processing Record 413 of Set 9 | kerema
# Processing Record 414 of Set 9 | el alto
# City not found. Skipping...
# Processing Record 415 of Set 9 | robat karim
# City not found. Skipping...
# Processing Record 416 of Set 9 | palmer
# Processing Record 417 of Set 9 | picota
# Processing Record 418 of Set 9 | veseloyarsk
# Processing Record 419 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 420 of Set 9 | mackay
# Processing Record 421 of Set 9 | malinovskiy
# Processing Record 422 of Set 9 | noumea
# Processing Record 423 of Set 9 | ahipara
# Processing Record 424 of Set 9 | ternate
# Processing Record 425 of Set 9 | acapulco
# Processing Record 426 of Set 9 | kushiro
# Processing Record 427 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 428 of Set 9 | faya
# Processing Record 429 of Set 9 | qingquan
# Processing Record 430 of Set 9 | gorele
# Processing Record 431 of Set 9 | maarianhamina
# Processing Record 432 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 433 of Set 9 | ostrovnoy
# Processing Record 434 of Set 9 | buenos aires
# City not found. Skipping...
# Processing Record 435 of Set 9 | camacupa
# Processing Record 436 of Set 9 | nishihara
# Processing Record 437 of Set 9 | crowley
# Processing Record 438 of Set 9 | komsomolskiy
# Processing Record 439 of Set 9 | takab
# Processing Record 440 of Set 9 | minna
# Processing Record 441 of Set 9 | nouadhibou
# Processing Record 442 of Set 9 | broken hill
# City not found. Skipping...
# Processing Record 443 of Set 9 | lovozero
# Processing Record 444 of Set 9 | salo
# Processing Record 445 of Set 9 | port-gentil
# Processing Record 446 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 447 of Set 9 | kaitangata
# Processing Record 448 of Set 9 | ayagoz
# Processing Record 449 of Set 9 | mackenzie
# Processing Record 450 of Set 9 | nushki
# Processing Record 451 of Set 9 | rorvik
# Processing Record 452 of Set 9 | cananeia
# Processing Record 453 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 454 of Set 9 | urumqi
# Processing Record 455 of Set 9 | ankazobe
# Processing Record 456 of Set 9 | ossora
# Processing Record 457 of Set 9 | havelock
# Processing Record 458 of Set 9 | hambantota
# Processing Record 460 of Set 10 | vitim
# Processing Record 461 of Set 10 | luau
# Processing Record 462 of Set 10 | nizhnyaya poyma
# City not found. Skipping...
# Processing Record 463 of Set 10 | saint george
# City not found. Skipping...
# Processing Record 464 of Set 10 | huntington
# Processing Record 465 of Set 10 | brewster
# Processing Record 466 of Set 10 | tateyama
# Processing Record 467 of Set 10 | harlingen
# Processing Record 468 of Set 10 | san patricio
# City not found. Skipping...
# Processing Record 469 of Set 10 | bubaque
# Processing Record 470 of Set 10 | namibe
# Processing Record 471 of Set 10 | homa bay
# City not found. Skipping...
# Processing Record 472 of Set 10 | hami
# Processing Record 473 of Set 10 | palu
# Processing Record 474 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 475 of Set 10 | sovetskiy
# Processing Record 476 of Set 10 | nyanza
# Processing Record 477 of Set 10 | broome
# Processing Record 478 of Set 10 | dombarovskiy
# Processing Record 479 of Set 10 | qaqortoq
# Processing Record 480 of Set 10 | pochutla
# Processing Record 481 of Set 10 | akdepe
# Processing Record 482 of Set 10 | ust-maya
# Processing Record 483 of Set 10 | camacha
# Processing Record 484 of Set 10 | oeiras do para
# City not found. Skipping...
# Processing Record 485 of Set 10 | loubomo
# Processing Record 486 of Set 10 | antofagasta
# Processing Record 487 of Set 10 | wad madani
# City not found. Skipping...
# Processing Record 488 of Set 10 | bilibino
# Processing Record 489 of Set 10 | paita
# Processing Record 490 of Set 10 | kutum
# Processing Record 491 of Set 10 | mittagong
# Processing Record 492 of Set 10 | fort nelson
# City not found. Skipping...
# Processing Record 493 of Set 10 | price
# Processing Record 494 of Set 10 | zonguldak
# Processing Record 495 of Set 10 | ust-tsilma
# Processing Record 496 of Set 10 | pangnirtung
# Processing Record 497 of Set 10 | mecca
# Processing Record 498 of Set 10 | bradford
# Processing Record 499 of Set 10 | vardo
# Processing Record 500 of Set 10 | kosa
# Processing Record 501 of Set 10 | kuppam
# Processing Record 502 of Set 10 | rosarito
# Processing Record 503 of Set 10 | saint-georges
# Processing Record 504 of Set 10 | gazojak
# Processing Record 505 of Set 10 | along
# Processing Record 506 of Set 10 | mizan teferi
# City not found. Skipping...
# Processing Record 507 of Set 10 | prado
# Processing Record 508 of Set 10 | kimbe
# Processing Record 509 of Set 10 | santa rosa
# City not found. Skipping...
# Processing Record 511 of Set 11 | lumeje
# Processing Record 512 of Set 11 | ganserndorf
# Processing Record 513 of Set 11 | yenagoa
# Processing Record 514 of Set 11 | frederikshavn
# Processing Record 515 of Set 11 | baykit
# Processing Record 516 of Set 11 | russell
# Processing Record 517 of Set 11 | kedrovyy
# Processing Record 518 of Set 11 | beyla
# Processing Record 519 of Set 11 | motala
# Processing Record 520 of Set 11 | verkhoyansk
# Processing Record 521 of Set 11 | tazovskiy
# Processing Record 522 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 523 of Set 11 | ocara
# Processing Record 524 of Set 11 | smithers
# Processing Record 525 of Set 11 | vila do maio
# City not found. Skipping...
# Processing Record 526 of Set 11 | mandalgovi
# Processing Record 527 of Set 11 | dunedin
# Processing Record 528 of Set 11 | angoche
# Processing Record 529 of Set 11 | lisala
# Processing Record 530 of Set 11 | bandarbeyla
# Processing Record 531 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 532 of Set 11 | yerbogachen
# Processing Record 533 of Set 11 | waipawa
# Processing Record 534 of Set 11 | bougouni
# Processing Record 535 of Set 11 | lahore
# Processing Record 536 of Set 11 | marystown
# Processing Record 537 of Set 11 | ushtobe
# Processing Record 538 of Set 11 | isiro
# Processing Record 539 of Set 11 | codrington
# Processing Record 540 of Set 11 | zhezkazgan
# Processing Record 541 of Set 11 | lahij
# Processing Record 542 of Set 11 | yellamanchili
# City not found. Skipping...
# Processing Record 543 of Set 11 | namatanai
# Processing Record 544 of Set 11 | juruti
# Processing Record 545 of Set 11 | svetlyy
# Processing Record 546 of Set 11 | liepaja
# Processing Record 547 of Set 11 | eyrarbakki
# Processing Record 548 of Set 11 | sohag
# Processing Record 549 of Set 11 | providencia
# Processing Record 550 of Set 11 | dunda
# Processing Record 551 of Set 11 | saryozek
# Processing Record 552 of Set 11 | shingu
# Processing Record 553 of Set 11 | miyako
# Processing Record 554 of Set 11 | balotra
# Processing Record 555 of Set 11 | stryn
# Processing Record 556 of Set 11 | sterling
# Processing Record 557 of Set 11 | douglas
# Processing Record 558 of Set 11 | pericos
# Processing Record 559 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 560 of Set 11 | calvinia
# Processing Record 562 of Set 12 | tezu
# Processing Record 563 of Set 12 | tucuman
# Processing Record 564 of Set 12 | ulladulla
# Processing Record 565 of Set 12 | nouakchott
# Processing Record 566 of Set 12 | ngaoundere
# Processing Record 567 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 568 of Set 12 | mikhaylovka
# Processing Record 569 of Set 12 | bermejo
# Processing Record 570 of Set 12 | berkovica
# Processing Record 571 of Set 12 | khandbari
# Processing Record 572 of Set 12 | codigoro
# Processing Record 573 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 574 of Set 12 | valparaiso
# Processing Record 575 of Set 12 | aykhal
# Processing Record 576 of Set 12 | teahupoo
# Processing Record 577 of Set 12 | kuandian
# Processing Record 578 of Set 12 | assiniboia
# Processing Record 579 of Set 12 | turukhansk
# Processing Record 580 of Set 12 | la macarena
# City not found. Skipping...
# Processing Record 581 of Set 12 | korla
# Processing Record 582 of Set 12 | lopatino
# Processing Record 583 of Set 12 | sivaki
# Processing Record 584 of Set 12 | yichun
# Processing Record 585 of Set 12 | marquette
# Processing Record 586 of Set 12 | timra
# Processing Record 587 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 588 of Set 12 | yumen
# Processing Record 589 of Set 12 | san juan
# City not found. Skipping...
# Processing Record 590 of Set 12 | mahuva
# Processing Record 591 of Set 12 | southbridge
# Processing Record 592 of Set 12 | karla
# Processing Record 593 of Set 12 | hohhot
# Processing Record 594 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 595 of Set 12 | olean
# Processing Record 596 of Set 12 | jalingo
# Processing Record 597 of Set 12 | alice springs
# City not found. Skipping...
# Processing Record 598 of Set 12 | bonnyville
# Processing Record 599 of Set 12 | oparino
# Processing Record 600 of Set 12 | quatre cocos
# City not found. Skipping...
# Processing Record 601 of Set 12 | thanh hoa
# City not found. Skipping...
# Processing Record 602 of Set 12 | kamennomostskiy
# Processing Record 603 of Set 12 | rawson
# Processing Record 604 of Set 12 | yanam
# Processing Record 605 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 606 of Set 12 | shitkino
# Processing Record 607 of Set 12 | mareeba
# Processing Record 608 of Set 12 | mao
# Processing Record 609 of Set 12 | olafsvik
# Processing Record 610 of Set 12 | maicao
# Processing Record 611 of Set 12 | westport
# Processing Record 613 of Set 13 | baie-comeau
# Processing Record 614 of Set 13 | pampa
# Processing Record 615 of Set 13 | varkaus
# Processing Record 616 of Set 13 | yabrud
# Processing Record 617 of Set 13 | cairns
# Processing Record 618 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 619 of Set 13 | krasnyy mayak
# City not found. Skipping...
# Processing Record 620 of Set 13 | bolshaya rechka
# City not found. Skipping...
# Processing Record 621 of Set 13 | galle
# Processing Record 622 of Set 13 | lompoc
# Processing Record 623 of Set 13 | gat
# Processing Record 624 of Set 13 | tuatapere
# Processing Record 625 of Set 13 | ferrol
# Processing Record 626 of Set 13 | ha tinh
# City not found. Skipping...
# Processing Record 627 of Set 13 | byron bay
# City not found. Skipping...
# Processing Record 628 of Set 13 | santa maria da boa vista
# City not found. Skipping...
# Processing Record 629 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 630 of Set 13 | hamina
# Processing Record 631 of Set 13 | mattru
# Processing Record 632 of Set 13 | jurado
# Processing Record 633 of Set 13 | iralaya
# Processing Record 634 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 635 of Set 13 | kaeo
# Processing Record 636 of Set 13 | chicama
# Processing Record 637 of Set 13 | huaiyuan
# Processing Record 638 of Set 13 | portel
# Processing Record 639 of Set 13 | clayton
# Processing Record 640 of Set 13 | naliya
# Processing Record 641 of Set 13 | liverpool
# Processing Record 642 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 643 of Set 13 | ayer molek
# City not found. Skipping...
# Processing Record 644 of Set 13 | fare
# Processing Record 645 of Set 13 | vestmannaeyjar
# Processing Record 646 of Set 13 | alugan
# Processing Record 647 of Set 13 | constitucion
# Processing Record 648 of Set 13 | mogadishu
# Processing Record 649 of Set 13 | jieshi
# Processing Record 650 of Set 13 | methoni
# Processing Record 651 of Set 13 | taiyuan
# Processing Record 652 of Set 13 | tangwani
# Processing Record 653 of Set 13 | dali
# Processing Record 654 of Set 13 | ahuimanu
# Processing Record 655 of Set 13 | beloha
# Processing Record 656 of Set 13 | lesnikovo
# Processing Record 657 of Set 13 | berbera
# Processing Record 658 of Set 13 | yanji
# Processing Record 659 of Set 13 | norton shores
# City not found. Skipping...
# Processing Record 660 of Set 13 | nexo
# Processing Record 661 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 662 of Set 13 | aksarka
# Processing Record 664 of Set 14 | itaguai
# Processing Record 665 of Set 14 | san quintin
# City not found. Skipping...
# Processing Record 666 of Set 14 | jumla
# Processing Record 667 of Set 14 | bitung
# Processing Record 668 of Set 14 | solnechnyy
# Processing Record 669 of Set 14 | sao geraldo do araguaia
# City not found. Skipping...
# Processing Record 670 of Set 14 | muli
# Processing Record 671 of Set 14 | hofu
# Processing Record 672 of Set 14 | minot
# Processing Record 673 of Set 14 | lipin bor
# City not found. Skipping...
# Processing Record 674 of Set 14 | carlsbad
# Processing Record 675 of Set 14 | spas-demensk
# Processing Record 676 of Set 14 | buala
# Processing Record 677 of Set 14 | jalu
# Processing Record 678 of Set 14 | mulchen
# Processing Record 679 of Set 14 | borama
# City not found. Skipping...
# Processing Record 680 of Set 14 | labuhan
# Processing Record 681 of Set 14 | guilin
# Processing Record 682 of Set 14 | zwedru
# Processing Record 683 of Set 14 | edgewater
# Processing Record 684 of Set 14 | roblin
# Processing Record 685 of Set 14 | talcahuano
# Processing Record 686 of Set 14 | annau
# Processing Record 687 of Set 14 | markova
# Processing Record 688 of Set 14 | myitkyina
# Processing Record 689 of Set 14 | arcata
# Processing Record 690 of Set 14 | husavik
# Processing Record 691 of Set 14 | sobolevo
# Processing Record 692 of Set 14 | cururupu
# Processing Record 693 of Set 14 | laguna
# Processing Record 694 of Set 14 | nelson bay
# City not found. Skipping...
# Processing Record 695 of Set 14 | constantine
# Processing Record 696 of Set 14 | mount vernon
# City not found. Skipping...
# Processing Record 697 of Set 14 | boralday
# Processing Record 698 of Set 14 | chadiza
# Processing Record 699 of Set 14 | isabela
# Processing Record 700 of Set 14 | barda
# Processing Record 701 of Set 14 | ulaangom
# Processing Record 702 of Set 14 | tongliao
# Processing Record 703 of Set 14 | muswellbrook
# Processing Record 704 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 705 of Set 14 | dom pedrito
# City not found. Skipping...
# Processing Record 706 of Set 14 | erbaa
# Processing Record 707 of Set 14 | nadym
# Processing Record 708 of Set 14 | kamensk-uralskiy
# Processing Record 709 of Set 14 | boa viagem
# City not found. Skipping...
# Processing Record 710 of Set 14 | karatau
# Processing Record 711 of Set 14 | jatara
# Processing Record 712 of Set 14 | rimbey
# Processing Record 713 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 715 of Set 15 | college
# Processing Record 716 of Set 15 | prince rupert
# City not found. Skipping...
# Processing Record 717 of Set 15 | sand springs
# City not found. Skipping...
# Processing Record 718 of Set 15 | port augusta
# City not found. Skipping...
# Processing Record 719 of Set 15 | lucapa
# Processing Record 720 of Set 15 | batemans bay
# City not found. Skipping...
# Processing Record 721 of Set 15 | toulepleu
# City not found. Skipping...
# Processing Record 722 of Set 15 | adilcevaz
# Processing Record 723 of Set 15 | kodino
# Processing Record 724 of Set 15 | grand-santi
# Processing Record 725 of Set 15 | bondo
# Processing Record 726 of Set 15 | fallon
# Processing Record 727 of Set 15 | muros
# Processing Record 728 of Set 15 | martapura
# Processing Record 729 of Set 15 | nome
# Processing Record 730 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 731 of Set 15 | mehran
# Processing Record 732 of Set 15 | russkaya polyana
# City not found. Skipping...
# Processing Record 733 of Set 15 | marawi
# Processing Record 734 of Set 15 | touros
# Processing Record 735 of Set 15 | mersing
# Processing Record 736 of Set 15 | guerrero
# Processing Record 737 of Set 15 | pechora
# Processing Record 738 of Set 15 | aswan
# Processing Record 739 of Set 15 | saint-augustin
# Processing Record 740 of Set 15 | tupik
# Processing Record 741 of Set 15 | nargana
# Processing Record 742 of Set 15 | guiren
# Processing Record 743 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 744 of Set 15 | horn
# Processing Record 745 of Set 15 | qianan
# Processing Record 746 of Set 15 | pennsville
# Processing Record 747 of Set 15 | taoudenni
# Processing Record 748 of Set 15 | innisfail
# Processing Record 749 of Set 15 | tsurib
# Processing Record 750 of Set 15 | morant bay
# City not found. Skipping...
# Processing Record 751 of Set 15 | flinders
# Processing Record 752 of Set 15 | dabakala
# Processing Record 753 of Set 15 | bathsheba
# Processing Record 754 of Set 15 | somoto
# Processing Record 755 of Set 15 | hare bay
# City not found. Skipping...
# Processing Record 756 of Set 15 | san fernando
# City not found. Skipping...
# Processing Record 757 of Set 15 | abu samrah
# City not found. Skipping...
# Processing Record 758 of Set 15 | pingliang
# Processing Record 759 of Set 15 | kazalinsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Zhigansk  66.7697  123.3711    -48.87        99          76
# 1           Sucua  -2.4667  -78.1667     86.74        45          20
# 2         Ushuaia -54.8000  -68.3000     58.66        47          75
# 3          Castro -24.7911  -50.0119     72.66        59          85
# 4  Saint-Philippe -21.3585   55.7679     78.35        87          88
# 5          Shache  38.4167   77.2406     27.43        50          69
# 6          Albany  42.6001  -73.9662     33.46        58          45
# 7       Carnarvon -24.8667  113.6333     71.67        83          75
# 8        Hermanus -34.4187   19.2345     65.80        85         100
# 9          Kodiak  57.7900 -152.4072     33.31        75          20
#
#    Wind Speed Current Description Country
# 0        3.36       broken clouds      RU
# 1        5.75          light rain      EC
# 2       14.97       broken clouds      AR
# 3        7.67     overcast clouds      BR
# 4       12.93     overcast clouds      RE
# 5        3.69       broken clouds      CN
# 6        1.01    scattered clouds      US
# 7       18.41       broken clouds      AU
# 8       13.20     overcast clouds      ZA
# 9        0.00          few clouds      US

# %%
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Zhigansk      RU  66.7697  123.3711    -48.87        99          76
# 1           Sucua      EC  -2.4667  -78.1667     86.74        45          20
# 2         Ushuaia      AR -54.8000  -68.3000     58.66        47          75
# 3          Castro      BR -24.7911  -50.0119     72.66        59          85
# 4  Saint-Philippe      RE -21.3585   55.7679     78.35        87          88
# 5          Shache      CN  38.4167   77.2406     27.43        50          69
# 6          Albany      US  42.6001  -73.9662     33.46        58          45
# 7       Carnarvon      AU -24.8667  113.6333     71.67        83          75
# 8        Hermanus      ZA -34.4187   19.2345     65.80        85         100
# 9          Kodiak      US  57.7900 -152.4072     33.31        75          20
#
#    Wind Speed Current Description
# 0        3.36       broken clouds
# 1        5.75          light rain
# 2       14.97       broken clouds
# 3        7.67     overcast clouds
# 4       12.93     overcast clouds
# 5        3.69       broken clouds
# 6        1.01    scattered clouds
# 7       18.41       broken clouds
# 8       13.20     overcast clouds
# 9        0.00          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_DataBase.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label="City_ID")
